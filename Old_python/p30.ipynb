# %%
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
def psum(n, p):
    m = [int(s)**p for s in str(n)]
    return sum(m)

# %%
psum(10000, 4)
# Out:
# 1

# %%
n = range(2, 1000000)
ns = []
for nn in n:
    ns.append(psum(nn, 5))

# %%
plt.figure()
plt.plot(n, ns, '.')
plt.plot([0, n[-1]], [0, n[-1]])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s = 0
for n in range(2, 300002):
    np = psum(n, 5)
    if n == np:
        print(n)
        s += n
# Out:
# 4150
# 4151
# 54748
# 92727
# 93084
# 194979

# %%
s
# Out:
# 443839
